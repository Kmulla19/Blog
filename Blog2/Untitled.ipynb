# %% [markdown]
# Process for webscrapping LinkedIn contact information for sales professionals

# %%
import pandas as pd
url = 'https://www.pro-football-reference.com/years/2021/fantasy.htm'
fantasy_standings_df = pd.read_html(url)[0]

# %%
fantasy_standings_df
# Out:
#     Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                     Rk             Player                 Tm
# 0                    1  Jonathan Taylor*+                IND
# 1                    2      Cooper Kupp*+                LAR
# 2                    3     Deebo Samuel*+                SFO
# 3                    4         Josh Allen                BUF
# 4                    5      Austin Ekeler                LAC
# ..                 ...                ...                ...
# 688                667    Travis Benjamin                SFO
# 689                668     Trenton Cannon                2TM
# 690                669       John Wolford                LAR
# 691                670         Josh Rosen                ATL
# 692                671    Diontae Spencer                DEN
#
#     Unnamed: 3_level_0 Unnamed: 4_level_0 Games     Passing             ...  \
#                FantPos                Age     G  GS     Cmp  Att   Yds  ...
# 0                   RB                 22    17  17       0    0     0  ...
# 1                   WR                 28    17  17       0    1     0  ...
# 2                   WR                 25    16  15       1    2    24  ...
# 3                   QB                 25    17  17     409  646  4407  ...
# 4                   RB                 26    16  16       0    0     0  ...
# ..                 ...                ...   ...  ..     ...  ...   ...  ...
# 688                NaN                 32    10   0       0    0     0  ...
# 689                 RB                 27    12   0       0    0     0  ...
# 690                 QB                 26     3   0       1    4     5  ...
# 691                 QB                 24     4   0       2   11    19  ...
# 692                 WR                 29    15   0       0    0     0  ...
#
#     Scoring           Fantasy
#          TD  2PM  2PP  FantPt    PPR   DKPt   FDPt  VBD PosRank OvRank
# 0        20  NaN  NaN     333  373.1  381.1  353.1  187       1      1
# 1        16    1  NaN     295  439.5  442.5  367.0  173       1      2
# 2        14  NaN  NaN     262  339.0  347.0  300.5  140       2      3
# 3         6    2    1     403  402.6  426.6  417.6  134       1      4
# 4        20    2  NaN     274  343.8  352.8  308.8  128       2      5
# ..      ...  ...  ...     ...    ...    ...    ...  ...     ...    ...
# 688       0  NaN  NaN      -2   -2.0   -1.0   -2.0  NaN     260    NaN
# 689       0  NaN  NaN      -2   -1.6   -0.6   -1.6  NaN     179    NaN
# 690       0  NaN  NaN      -2   -1.9   -0.9   -0.9  NaN      84    NaN
# 691       0  NaN  NaN      -3   -3.2   -1.2   -1.2  NaN      85    NaN
# 692       0  NaN  NaN      -4   -3.3   -1.3   -3.8  NaN     261    NaN
#
# [693 rows x 33 columns]

# %%
tm_url = 'https://www.pro-football-reference.com/years/2021/'
AFC_standings_df = pd.read_html(tm_url)[0]

# %%
AFC_standings_df
# Out:
#                        Tm          W          L          T       W-L%  \
# 0                AFC East   AFC East   AFC East   AFC East   AFC East
# 1          Buffalo Bills*         11          6          0       .647
# 2   New England Patriots+         10          7          0       .588
# 3          Miami Dolphins          9          8          0       .529
# 4           New York Jets          4         13          0       .235
# 5               AFC North  AFC North  AFC North  AFC North  AFC North
# 6     Cincinnati Bengals*         10          7          0       .588
# 7    Pittsburgh Steelers+          9          7          1       .559
# 8        Cleveland Browns          8          9          0       .471
# 9        Baltimore Ravens          8          9          0       .471
# 10              AFC South  AFC South  AFC South  AFC South  AFC South
# 11      Tennessee Titans*         12          5          0       .706
# 12     Indianapolis Colts          9          8          0       .529
# 13         Houston Texans          4         13          0       .235
# 14   Jacksonville Jaguars          3         14          0       .176
# 15               AFC West   AFC West   AFC West   AFC West   AFC West
# 16    Kansas City Chiefs*         12          5          0       .706
# 17     Las Vegas Raiders+         10          7          0       .588
# 18   Los Angeles Chargers          9          8          0       .529
# 19         Denver Broncos          7         10          0       .412
#
#            PF         PA         PD        MoV        SoS        SRS  \
# 0    AFC East   AFC East   AFC East   AFC East   AFC East   AFC East
# 1         483        289        194       11.4       -1.6        9.8
# 2         462        303        159        9.4       -0.9        8.5
# 3         341        373        -32       -1.9       -0.8       -2.7
# 4         310        504       -194      -11.4        1.0      -10.4
# 5   AFC North  AFC North  AFC North  AFC North  AFC North  AFC North
# 6         460        376         84        4.9       -1.9        3.1
# 7         343        398        -55       -3.2        0.8       -2.5
# 8         349        371        -22       -1.3        0.0       -1.3
# 9         387        392         -5       -0.3        0.0       -0.3
# 10  AFC South  AFC South  AFC South  AFC South  AFC South  AFC South
# 11        419        354         65        3.8       -0.4        3.4
# 12        451        365         86        5.1       -0.6        4.4
# 13        280        452       -172      -10.1        0.4       -9.7
# 14        253        457       -204      -12.0        0.6      -11.4
# 15   AFC West   AFC West   AFC West   AFC West   AFC West   AFC West
# 16        480        364        116        6.8        0.6        7.4
# 17        374        439        -65       -3.8        0.6       -3.3
# 18        474        459         15        0.9        0.2        1.1
# 19        335        322         13        0.8       -1.3       -0.5
#
#          OSRS       DSRS
# 0    AFC East   AFC East
# 1         5.0        4.8
# 2         3.6        4.8
# 3        -3.1        0.3
# 4        -3.6       -6.7
# 5   AFC North  AFC North
# 6         3.4       -0.3
# 7        -2.6        0.1
# 8        -2.7        1.3
# 9        -0.3        0.0
# 10  AFC South  AFC South
# 11        1.8        1.6
# 12        3.3        1.1
# 13       -6.3       -3.4
# 14       -7.7       -3.7
# 15   AFC West   AFC West
# 16        5.4        2.0
# 17       -0.7       -2.6
# 18        5.3       -4.2
# 19       -4.7        4.2

# %%
AFC_filter = AFC_standings_df['Tm'].str.contains('AFC') == False

# %%
AFC_standings_df = AFC_standings_df.loc[AFC_filter].copy()

# %%
AFC_standings_df
# Out:
#                        Tm   W   L  T  W-L%   PF   PA    PD    MoV   SoS  \
# 1          Buffalo Bills*  11   6  0  .647  483  289   194   11.4  -1.6
# 2   New England Patriots+  10   7  0  .588  462  303   159    9.4  -0.9
# 3          Miami Dolphins   9   8  0  .529  341  373   -32   -1.9  -0.8
# 4           New York Jets   4  13  0  .235  310  504  -194  -11.4   1.0
# 6     Cincinnati Bengals*  10   7  0  .588  460  376    84    4.9  -1.9
# 7    Pittsburgh Steelers+   9   7  1  .559  343  398   -55   -3.2   0.8
# 8        Cleveland Browns   8   9  0  .471  349  371   -22   -1.3   0.0
# 9        Baltimore Ravens   8   9  0  .471  387  392    -5   -0.3   0.0
# 11      Tennessee Titans*  12   5  0  .706  419  354    65    3.8  -0.4
# 12     Indianapolis Colts   9   8  0  .529  451  365    86    5.1  -0.6
# 13         Houston Texans   4  13  0  .235  280  452  -172  -10.1   0.4
# 14   Jacksonville Jaguars   3  14  0  .176  253  457  -204  -12.0   0.6
# 16    Kansas City Chiefs*  12   5  0  .706  480  364   116    6.8   0.6
# 17     Las Vegas Raiders+  10   7  0  .588  374  439   -65   -3.8   0.6
# 18   Los Angeles Chargers   9   8  0  .529  474  459    15    0.9   0.2
# 19         Denver Broncos   7  10  0  .412  335  322    13    0.8  -1.3
#
#       SRS  OSRS  DSRS
# 1     9.8   5.0   4.8
# 2     8.5   3.6   4.8
# 3    -2.7  -3.1   0.3
# 4   -10.4  -3.6  -6.7
# 6     3.1   3.4  -0.3
# 7    -2.5  -2.6   0.1
# 8    -1.3  -2.7   1.3
# 9    -0.3  -0.3   0.0
# 11    3.4   1.8   1.6
# 12    4.4   3.3   1.1
# 13   -9.7  -6.3  -3.4
# 14  -11.4  -7.7  -3.7
# 16    7.4   5.4   2.0
# 17   -3.3  -0.7  -2.6
# 18    1.1   5.3  -4.2
# 19   -0.5  -4.7   4.2

# %%
tm_url = 'https://www.pro-football-reference.com/years/2021/'
NFC_standings_df = pd.read_html(tm_url)[1]

# %%
NFC_standings_df
# Out:
#                           Tm          W          L          T       W-L%  \
# 0                   NFC East   NFC East   NFC East   NFC East   NFC East
# 1            Dallas Cowboys*         12          5          0       .706
# 2       Philadelphia Eagles+          9          8          0       .529
# 3   Washington Football Team          7         10          0       .412
# 4            New York Giants          4         13          0       .235
# 5                  NFC North  NFC North  NFC North  NFC North  NFC North
# 6         Green Bay Packers*         13          4          0       .765
# 7          Minnesota Vikings          8          9          0       .471
# 8              Chicago Bears          6         11          0       .353
# 9              Detroit Lions          3         13          1       .206
# 10                 NFC South  NFC South  NFC South  NFC South  NFC South
# 11     Tampa Bay Buccaneers*         13          4          0       .765
# 12        New Orleans Saints          9          8          0       .529
# 13           Atlanta Falcons          7         10          0       .412
# 14         Carolina Panthers          5         12          0       .294
# 15                  NFC West   NFC West   NFC West   NFC West   NFC West
# 16         Los Angeles Rams*         12          5          0       .706
# 17        Arizona Cardinals+         11          6          0       .647
# 18      San Francisco 49ers+         10          7          0       .588
# 19          Seattle Seahawks          7         10          0       .412
#
#            PF         PA         PD        MoV        SoS        SRS  \
# 0    NFC East   NFC East   NFC East   NFC East   NFC East   NFC East
# 1         530        358        172       10.1       -0.2        9.9
# 2         444        385         59        3.5       -1.0        2.5
# 3         335        434        -99       -5.8        1.6       -4.2
# 4         258        416       -158       -9.3        1.0       -8.3
# 5   NFC North  NFC North  NFC North  NFC North  NFC North  NFC North
# 6         450        371         79        4.6       -0.2        4.4
# 7         425        426         -1       -0.1        0.3        0.3
# 8         311        407        -96       -5.6        0.5       -5.2
# 9         325        467       -142       -8.4        0.6       -7.8
# 10  NFC South  NFC South  NFC South  NFC South  NFC South  NFC South
# 11        511        353        158        9.3       -0.7        8.6
# 12        364        335         29        1.7        0.3        2.0
# 13        313        459       -146       -8.6        0.1       -8.5
# 14        304        404       -100       -5.9        0.4       -5.5
# 15   NFC West   NFC West   NFC West   NFC West   NFC West   NFC West
# 16        460        372         88        5.2        0.1        5.3
# 17        449        366         83        4.9        0.3        5.2
# 18        427        365         62        3.6        0.1        3.8
# 19        395        366         29        1.7        0.2        1.9
#
#          OSRS       DSRS
# 0    NFC East   NFC East
# 1         8.2        1.7
# 2         2.6       -0.1
# 3        -2.7       -1.5
# 4        -7.7       -0.6
# 5   NFC North  NFC North
# 6         3.5        1.0
# 7         1.9       -1.6
# 8        -4.9       -0.3
# 9        -3.5       -4.3
# 10  NFC South  NFC South
# 11        7.3        1.3
# 12       -1.5        3.6
# 13       -4.2       -4.3
# 14       -5.0       -0.5
# 15   NFC West   NFC West
# 16        4.2        1.1
# 17        3.6        1.6
# 18        1.8        1.9
# 19        0.4        1.5

# %%
NFC_filter = NFC_standings_df['Tm'].str.contains('NFC') == False

# %%
NFC_standings_df = NFC_standings_df.loc[NFC_filter].copy()

# %%
NFC_standings_df
# Out:
#                           Tm   W   L  T  W-L%   PF   PA    PD   MoV   SoS  \
# 1            Dallas Cowboys*  12   5  0  .706  530  358   172  10.1  -0.2
# 2       Philadelphia Eagles+   9   8  0  .529  444  385    59   3.5  -1.0
# 3   Washington Football Team   7  10  0  .412  335  434   -99  -5.8   1.6
# 4            New York Giants   4  13  0  .235  258  416  -158  -9.3   1.0
# 6         Green Bay Packers*  13   4  0  .765  450  371    79   4.6  -0.2
# 7          Minnesota Vikings   8   9  0  .471  425  426    -1  -0.1   0.3
# 8              Chicago Bears   6  11  0  .353  311  407   -96  -5.6   0.5
# 9              Detroit Lions   3  13  1  .206  325  467  -142  -8.4   0.6
# 11     Tampa Bay Buccaneers*  13   4  0  .765  511  353   158   9.3  -0.7
# 12        New Orleans Saints   9   8  0  .529  364  335    29   1.7   0.3
# 13           Atlanta Falcons   7  10  0  .412  313  459  -146  -8.6   0.1
# 14         Carolina Panthers   5  12  0  .294  304  404  -100  -5.9   0.4
# 16         Los Angeles Rams*  12   5  0  .706  460  372    88   5.2   0.1
# 17        Arizona Cardinals+  11   6  0  .647  449  366    83   4.9   0.3
# 18      San Francisco 49ers+  10   7  0  .588  427  365    62   3.6   0.1
# 19          Seattle Seahawks   7  10  0  .412  395  366    29   1.7   0.2
#
#      SRS  OSRS  DSRS
# 1    9.9   8.2   1.7
# 2    2.5   2.6  -0.1
# 3   -4.2  -2.7  -1.5
# 4   -8.3  -7.7  -0.6
# 6    4.4   3.5   1.0
# 7    0.3   1.9  -1.6
# 8   -5.2  -4.9  -0.3
# 9   -7.8  -3.5  -4.3
# 11   8.6   7.3   1.3
# 12   2.0  -1.5   3.6
# 13  -8.5  -4.2  -4.3
# 14  -5.5  -5.0  -0.5
# 16   5.3   4.2   1.1
# 17   5.2   3.6   1.6
# 18   3.8   1.8   1.9
# 19   1.9   0.4   1.5

# %%
NFL_standings_df = pd.concat([AFC_standings_df, NFC_standings_df])

# %%
NFL_standings_df
# Out:
#                           Tm   W   L  T  W-L%   PF   PA    PD    MoV   SoS  \
# 1             Buffalo Bills*  11   6  0  .647  483  289   194   11.4  -1.6
# 2      New England Patriots+  10   7  0  .588  462  303   159    9.4  -0.9
# 3             Miami Dolphins   9   8  0  .529  341  373   -32   -1.9  -0.8
# 4              New York Jets   4  13  0  .235  310  504  -194  -11.4   1.0
# 6        Cincinnati Bengals*  10   7  0  .588  460  376    84    4.9  -1.9
# 7       Pittsburgh Steelers+   9   7  1  .559  343  398   -55   -3.2   0.8
# 8           Cleveland Browns   8   9  0  .471  349  371   -22   -1.3   0.0
# 9           Baltimore Ravens   8   9  0  .471  387  392    -5   -0.3   0.0
# 11         Tennessee Titans*  12   5  0  .706  419  354    65    3.8  -0.4
# 12        Indianapolis Colts   9   8  0  .529  451  365    86    5.1  -0.6
# 13            Houston Texans   4  13  0  .235  280  452  -172  -10.1   0.4
# 14      Jacksonville Jaguars   3  14  0  .176  253  457  -204  -12.0   0.6
# 16       Kansas City Chiefs*  12   5  0  .706  480  364   116    6.8   0.6
# 17        Las Vegas Raiders+  10   7  0  .588  374  439   -65   -3.8   0.6
# 18      Los Angeles Chargers   9   8  0  .529  474  459    15    0.9   0.2
# 19            Denver Broncos   7  10  0  .412  335  322    13    0.8  -1.3
# 1            Dallas Cowboys*  12   5  0  .706  530  358   172   10.1  -0.2
# 2       Philadelphia Eagles+   9   8  0  .529  444  385    59    3.5  -1.0
# 3   Washington Football Team   7  10  0  .412  335  434   -99   -5.8   1.6
# 4            New York Giants   4  13  0  .235  258  416  -158   -9.3   1.0
# 6         Green Bay Packers*  13   4  0  .765  450  371    79    4.6  -0.2
# 7          Minnesota Vikings   8   9  0  .471  425  426    -1   -0.1   0.3
# 8              Chicago Bears   6  11  0  .353  311  407   -96   -5.6   0.5
# 9              Detroit Lions   3  13  1  .206  325  467  -142   -8.4   0.6
# 11     Tampa Bay Buccaneers*  13   4  0  .765  511  353   158    9.3  -0.7
# 12        New Orleans Saints   9   8  0  .529  364  335    29    1.7   0.3
# 13           Atlanta Falcons   7  10  0  .412  313  459  -146   -8.6   0.1
# 14         Carolina Panthers   5  12  0  .294  304  404  -100   -5.9   0.4
# 16         Los Angeles Rams*  12   5  0  .706  460  372    88    5.2   0.1
# 17        Arizona Cardinals+  11   6  0  .647  449  366    83    4.9   0.3
# 18      San Francisco 49ers+  10   7  0  .588  427  365    62    3.6   0.1
# 19          Seattle Seahawks   7  10  0  .412  395  366    29    1.7   0.2
#
#       SRS  OSRS  DSRS
# 1     9.8   5.0   4.8
# 2     8.5   3.6   4.8
# 3    -2.7  -3.1   0.3
# 4   -10.4  -3.6  -6.7
# 6     3.1   3.4  -0.3
# 7    -2.5  -2.6   0.1
# 8    -1.3  -2.7   1.3
# 9    -0.3  -0.3   0.0
# 11    3.4   1.8   1.6
# 12    4.4   3.3   1.1
# 13   -9.7  -6.3  -3.4
# 14  -11.4  -7.7  -3.7
# 16    7.4   5.4   2.0
# 17   -3.3  -0.7  -2.6
# 18    1.1   5.3  -4.2
# 19   -0.5  -4.7   4.2
# 1     9.9   8.2   1.7
# 2     2.5   2.6  -0.1
# 3    -4.2  -2.7  -1.5
# 4    -8.3  -7.7  -0.6
# 6     4.4   3.5   1.0
# 7     0.3   1.9  -1.6
# 8    -5.2  -4.9  -0.3
# 9    -7.8  -3.5  -4.3
# 11    8.6   7.3   1.3
# 12    2.0  -1.5   3.6
# 13   -8.5  -4.2  -4.3
# 14   -5.5  -5.0  -0.5
# 16    5.3   4.2   1.1
# 17    5.2   3.6   1.6
# 18    3.8   1.8   1.9
# 19    1.9   0.4   1.5

# %%
NFL_standings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 1 to 19
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tm      32 non-null     object
#  1   W       32 non-null     object
#  2   L       32 non-null     object
#  3   T       32 non-null     object
#  4   W-L%    32 non-null     object
#  5   PF      32 non-null     object
#  6   PA      32 non-null     object
#  7   PD      32 non-null     object
#  8   MoV     32 non-null     object
#  9   SoS     32 non-null     object
#  10  SRS     32 non-null     object
#  11  OSRS    32 non-null     object
#  12  DSRS    32 non-null     object
# dtypes: object(13)
# memory usage: 3.5+ KB

# %%
NFL_standings_df
